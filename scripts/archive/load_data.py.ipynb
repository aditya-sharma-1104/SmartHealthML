# %%
# %pip install pandas numpy scikit-learn matplotlib seaborn joblib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 12.5 MB/s eta 0:00:01
#    --------- ------------------------------ 1.8/8.1 MB 4.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.1 MB 3.9 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.1 MB 3.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 3.2 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.1 MB 3.2 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.1 MB 3.1 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import os

# Check available files in current directory
print("Files in current directory:")
print(os.listdir('.'))

# Update paths - adjust based on where your CSV files are located
try:
    disease = pd.read_csv("data/idsp_synthetic_2016_2025.csv")
    water = pd.read_csv("data/Indian_water_data.csv")
    rainfall = pd.read_csv("data/rainfall_area-wt_India_1901-2015.csv")
    weather = pd.read_csv("data/Weather Data in India from 1901 to 2017.csv")
except FileNotFoundError as e:
    print(f"Error: {e}")
    print("Please ensure the CSV files are in the 'data/' directory")

print("Disease:", disease.shape)
print("Water:", water.shape)
print("Rainfall:", rainfall.shape)
print("Weather:", weather.shape)
# Out:
# Files in current directory:
# ['load_data.py.ipynb']
# Error: [Errno 2] No such file or directory: 'data/idsp_synthetic_2016_2025.csv'
# Please ensure the CSV files are in the 'data/' directory
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 18
#      15     print(f"Error: {e}")
#      16     print("Please ensure the CSV files are in the 'data/' directory")
# ---> 18 print("Disease:", disease.shape)
#      19 print("Water:", water.shape)
#      20 print("Rainfall:", rainfall.shape)
#
# NameError: name 'disease' is not defined
